# %% [markdown]
#  # Pandas for Data Science

# %% [markdown]
# importing  package's

# %%
import pandas as pd

# %% [markdown]
# creating data frame using pandas

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])

# %% [markdown]
# printing data frame have diffrent approach's

# %%
# using df name
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# head () return the first 5 rows of DataFrame

# %%
df.head()
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# with columns name

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'])

# %%
# head
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# with columns and index names

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])

# %% [markdown]
# head ()

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %% [markdown]
# if u want specified number row

# %%
df.head(1) # 1 row number
# Out:
#    A  B  C
# x  1  2  3

# %% [markdown]
# if u want specified number row

# %%
# head(2)
df.head(2)
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6

# %% [markdown]
# i want last elements use tail function

# %%
df.tail(1) # last element 1
# Out:
#    A  B  C
# z  7  8  9

# %% [markdown]
# for last 2 rows

# %%
df.tail(2)
# Out:
#    A  B  C
# y  4  5  6
# z  7  8  9

# %% [markdown]
# for knowing columns  names

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# for knowing indexs

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %% [markdown]
# for knowing information about data frame  use info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %% [markdown]
# describe  return count mean std min 25 50 75 % max

# %%
# describe  return count mean std min 25 50 75 % max
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %% [markdown]
# for spcific column

# %%
# for spcific column
df['A']
# Out:
# x    1
# y    4
# z    7
# Name: A, dtype: int64

# %%
# for specific column
df['B']
# Out:
# x    2
# y    5
# z    8
# Name: B, dtype: int64

# %%
# for specific column

df['C']
# Out:
# x    3
# y    6
# z    9
# Name: C, dtype: int64

# %% [markdown]
#  unique values

# %%
#
df["A"].unique()
# Out:
# array([1, 4, 7])

# %% [markdown]
# for shape  of data frame (row,col)

# %%
# for shape  of data frame (row,col)
df.shape
# Out:
# (3, 3)

# %% [markdown]
# size

# %%
# size 3*3
df.size
# Out:
# 9

# %% [markdown]
# Loading in DataFrame from files

# %%
# loading csv file
df1=pd.read_csv('california_housing_test.csv')

# %% [markdown]
# reading xlsx file

# %%
# reading xlsx file

df2=pd.read_csv('mnist_test.csv')

# %%
# head()
df1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Accessing Data with Pandas

# %%
# using varible of dataframe
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# df1

df1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
# df2
#df2

# %%
print(df1)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
# using display
display(df)
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# accessing

df1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
# head for df2
#df2.head()

# %%
# using loc with one value
df.iloc[:,[0]]
# Out:
#    A
# x  1
# y  4
# z  7

# %%
# usingiloc with mutiple

df.iloc[:,[0,1,2]]
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# # usingiloc with mutiple
# iloc[start:stop,[index]]
df.iloc[0:2,[0,1,2]]
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6

# %%
# dataframe using also will get ouput

df.index=df['A']

df
# Out:
#    A  B  C
# A
# 1  1  2  3
# 4  4  5  6
# 7  7  8  9

# %%
# now cheeck


df.loc[0:4]
# Out:
#    A  B  C
# A
# 1  1  2  3
# 4  4  5  6

# %%
#
df.loc[1:3,'C']
# Out:
# A
# 1    3
# Name: C, dtype: int64

# %%
import pandas as pd

# %%
df_c=pd.read_csv('/content/coffee.csv')

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# sort_values
df_c.sort_values('Units Sold')
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# sort_values and with parameter
df_c.sort_values('Units Sold',ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
df_c.sort_values(['Units Sold','Coffee Type'])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# using for and iterrows()

for index ,row in df_c.iterrows():
  print(index)

  print(row['Units Sold'])
# Out:
# 0
# 25
# 1
# 15
# 2
# 30
# 3
# 20
# 4
# 35
# 5
# 25
# 6
# 40
# 7
# 30
# 8
# 45
# 9
# 35
# 10
# 45
# 11
# 35
# 12
# 45
# 13
# 35

# %% [markdown]
# Filtering Data

# %%
# condition of df_c

df_c[df_c['Units Sold'] >20]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# filter
df_c[(df_c['Units Sold']) & (df_c['Coffee Type']=='Latte')]
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 5   Wednesday       Latte          25
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
# contain function
df_c[df_c['Day'].str.contains('Monday')]
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          15

# %%
 # contain function with paramter case means u can give any case like upper or lower
df_c[df_c['Coffee Type'].str.contains('Espresso',case=False)]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# or condition
df_c[df_c['Coffee Type'].str.contains('monday|espresso|latte',case=False)]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
 #  isin()

df_c[df_c['Day'].isin(['Monday'])]
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          15

# %%
# query function


df_c.query('Day=="Sunday"')
# Out:
#        Day Coffee Type  Units Sold
# 12  Sunday    Espresso          45
# 13  Sunday       Latte          35

# %% [markdown]
# Adding/Removeing Columns

# %%
df_c['Price']=5.00

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso          25    5.0
# 1      Monday       Latte          15    5.0
# 2     Tuesday    Espresso          30    5.0
# 3     Tuesday       Latte          20    5.0
# 4   Wednesday    Espresso          35    5.0
# 5   Wednesday       Latte          25    5.0
# 6    Thursday    Espresso          40    5.0
# 7    Thursday       Latte          30    5.0
# 8      Friday    Espresso          45    5.0
# 9      Friday       Latte          35    5.0
# 10   Saturday    Espresso          45    5.0
# 11   Saturday       Latte          35    5.0
# 12     Sunday    Espresso          45    5.0
# 13     Sunday       Latte          35    5.0

# %%
# head()
df_c.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25    5.0
# 1     Monday       Latte          15    5.0
# 2    Tuesday    Espresso          30    5.0
# 3    Tuesday       Latte          20    5.0
# 4  Wednesday    Espresso          35    5.0

# %%
import numpy as np

# %%
df_c['new_price']=np.where(df_c['Coffee Type']=='Espresso',3.9,5.0)

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold  Price  new_price
# 0      Monday    Espresso          25    5.0        3.9
# 1      Monday       Latte          15    5.0        5.0
# 2     Tuesday    Espresso          30    5.0        3.9
# 3     Tuesday       Latte          20    5.0        5.0
# 4   Wednesday    Espresso          35    5.0        3.9
# 5   Wednesday       Latte          25    5.0        5.0
# 6    Thursday    Espresso          40    5.0        3.9
# 7    Thursday       Latte          30    5.0        5.0
# 8      Friday    Espresso          45    5.0        3.9
# 9      Friday       Latte          35    5.0        5.0
# 10   Saturday    Espresso          45    5.0        3.9
# 11   Saturday       Latte          35    5.0        5.0
# 12     Sunday    Espresso          45    5.0        3.9
# 13     Sunday       Latte          35    5.0        5.0

# %%
 df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
#  3   Price        14 non-null     float64
#  4   new_price    14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 688.0+ bytes

# %% [markdown]
# Handling Null Values

# %%
df_c.loc[[0,1],'Units Sold']=np.nan

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold  Price  new_price
# 0      Monday    Espresso         NaN    5.0        3.9
# 1      Monday       Latte         NaN    5.0        5.0
# 2     Tuesday    Espresso        30.0    5.0        3.9
# 3     Tuesday       Latte        20.0    5.0        5.0
# 4   Wednesday    Espresso        35.0    5.0        3.9
# 5   Wednesday       Latte        25.0    5.0        5.0
# 6    Thursday    Espresso        40.0    5.0        3.9
# 7    Thursday       Latte        30.0    5.0        5.0
# 8      Friday    Espresso        45.0    5.0        3.9
# 9      Friday       Latte        35.0    5.0        5.0
# 10   Saturday    Espresso        45.0    5.0        3.9
# 11   Saturday       Latte        35.0    5.0        5.0
# 12     Sunday    Espresso        45.0    5.0        3.9
# 13     Sunday       Latte        35.0    5.0        5.0

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   12 non-null     float64
#  3   Price        14 non-null     float64
#  4   new_price    14 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 688.0+ bytes

# %% [markdown]
# for knowing null is_null()

# %%
df_c.isnull()
# Out:
#       Day  Coffee Type  Units Sold  Price  new_price
# 0   False        False        True  False      False
# 1   False        False        True  False      False
# 2   False        False       False  False      False
# 3   False        False       False  False      False
# 4   False        False       False  False      False
# 5   False        False       False  False      False
# 6   False        False       False  False      False
# 7   False        False       False  False      False
# 8   False        False       False  False      False
# 9   False        False       False  False      False
# 10  False        False       False  False      False
# 11  False        False       False  False      False
# 12  False        False       False  False      False
# 13  False        False       False  False      False

# %% [markdown]
# for suming null

# %%
df_c.isnull().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# Price          0
# new_price      0
# dtype: int64

# %% [markdown]
# for filling null values

# %%
df_c.fillna(df_c['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  Price  new_price
# 0      Monday    Espresso        35.0    5.0        3.9
# 1      Monday       Latte        35.0    5.0        5.0
# 2     Tuesday    Espresso        30.0    5.0        3.9
# 3     Tuesday       Latte        20.0    5.0        5.0
# 4   Wednesday    Espresso        35.0    5.0        3.9
# 5   Wednesday       Latte        25.0    5.0        5.0
# 6    Thursday    Espresso        40.0    5.0        3.9
# 7    Thursday       Latte        30.0    5.0        5.0
# 8      Friday    Espresso        45.0    5.0        3.9
# 9      Friday       Latte        35.0    5.0        5.0
# 10   Saturday    Espresso        45.0    5.0        3.9
# 11   Saturday       Latte        35.0    5.0        5.0
# 12     Sunday    Espresso        45.0    5.0        3.9
# 13     Sunday       Latte        35.0    5.0        5.0

# %%
# Interpolation return null valuees
df_c.fillna(df_c['Units Sold'].interpolate())
# Out:
#           Day Coffee Type  Units Sold  Price  new_price
# 0      Monday    Espresso         NaN    5.0        3.9
# 1      Monday       Latte         NaN    5.0        5.0
# 2     Tuesday    Espresso        30.0    5.0        3.9
# 3     Tuesday       Latte        20.0    5.0        5.0
# 4   Wednesday    Espresso        35.0    5.0        3.9
# 5   Wednesday       Latte        25.0    5.0        5.0
# 6    Thursday    Espresso        40.0    5.0        3.9
# 7    Thursday       Latte        30.0    5.0        5.0
# 8      Friday    Espresso        45.0    5.0        3.9
# 9      Friday       Latte        35.0    5.0        5.0
# 10   Saturday    Espresso        45.0    5.0        3.9
# 11   Saturday       Latte        35.0    5.0        5.0
# 12     Sunday    Espresso        45.0    5.0        3.9
# 13     Sunday       Latte        35.0    5.0        5.0

# %%
# filling null forl all unit sold column
df_c['Units Sold']=np.nan

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold  Price  new_price
# 0      Monday    Espresso         NaN    5.0        3.9
# 1      Monday       Latte         NaN    5.0        5.0
# 2     Tuesday    Espresso         NaN    5.0        3.9
# 3     Tuesday       Latte         NaN    5.0        5.0
# 4   Wednesday    Espresso         NaN    5.0        3.9
# 5   Wednesday       Latte         NaN    5.0        5.0
# 6    Thursday    Espresso         NaN    5.0        3.9
# 7    Thursday       Latte         NaN    5.0        5.0
# 8      Friday    Espresso         NaN    5.0        3.9
# 9      Friday       Latte         NaN    5.0        5.0
# 10   Saturday    Espresso         NaN    5.0        3.9
# 11   Saturday       Latte         NaN    5.0        5.0
# 12     Sunday    Espresso         NaN    5.0        3.9
# 13     Sunday       Latte         NaN    5.0        5.0

# %%
# out of 14  12 is nan 2 is 15.0
df_c.loc[[1,2],'Units Sold']=15

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold  Price  new_price
# 0      Monday    Espresso         NaN    5.0        3.9
# 1      Monday       Latte        15.0    5.0        5.0
# 2     Tuesday    Espresso        15.0    5.0        3.9
# 3     Tuesday       Latte         NaN    5.0        5.0
# 4   Wednesday    Espresso         NaN    5.0        3.9
# 5   Wednesday       Latte         NaN    5.0        5.0
# 6    Thursday    Espresso         NaN    5.0        3.9
# 7    Thursday       Latte         NaN    5.0        5.0
# 8      Friday    Espresso         NaN    5.0        3.9
# 9      Friday       Latte         NaN    5.0        5.0
# 10   Saturday    Espresso         NaN    5.0        3.9
# 11   Saturday       Latte         NaN    5.0        5.0
# 12     Sunday    Espresso         NaN    5.0        3.9
# 13     Sunday       Latte         NaN    5.0        5.0

# %%
df_c.loc[[2,3],'Units Sold']=np.nan

# %%
df_c['Units Sold'].interpolate()
# Out:
# 0      NaN
# 1     15.0
# 2     15.0
# 3     15.0
# 4     15.0
# 5     15.0
# 6     15.0
# 7     15.0
# 8     15.0
# 9     15.0
# 10    15.0
# 11    15.0
# 12    15.0
# 13    15.0
# Name: Units Sold, dtype: float64

# %%
# loading df
df_c=pd.read_csv('/content/coffee.csv')

# %% [markdown]
# for droping null use dropna() function

# %%
df_c.dropna()
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df_c.dropna(subset=['Units Sold'],inplace=True)

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# Aggregating Data

# %%
df_c.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# calculating count of each type of tea
df_c['Coffee Type'].value_counts()
# Out:
# Coffee Type
# Espresso    7
# Latte       7
# Name: count, dtype: int64

# %%
df_c['Units Sold']=df_c['Units Sold'].interpolate()

# %%
df_c
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# groupby


df_c.groupby(['Coffee Type','Units Sold']).sum()
# Out:
#                                          Day
# Coffee Type Units Sold
# Espresso    25                        Monday
#             30                       Tuesday
#             35                     Wednesday
#             40                      Thursday
#             45          FridaySaturdaySunday
# Latte       15                        Monday
#             20                       Tuesday
#             25                     Wednesday
#             30                      Thursday
#             35          FridaySaturdaySunday

# %%
# group by
df_c.groupby(['Day'])['Units Sold'].sum()
# Out:
# Day
# Friday       80
# Monday       40
# Saturday     80
# Sunday       80
# Thursday     70
# Tuesday      50
# Wednesday    60
# Name: Units Sold, dtype: int64

# %%
df_c.mode()
# Out:
#          Day Coffee Type  Units Sold
# 0     Friday    Espresso        35.0
# 1     Monday       Latte         NaN
# 2   Saturday         NaN         NaN
# 3     Sunday         NaN         NaN
# 4   Thursday         NaN         NaN
# 5    Tuesday         NaN         NaN
# 6  Wednesday         NaN         NaN

# %%
# groupby sum()
df_c.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    265
# Latte       195
# Name: Units Sold, dtype: int64

# %%
# mean()

df_c.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    37.857143
# Latte       27.857143
# Name: Units Sold, dtype: float64

# %%
df_c

#df_c.groupby(['Coffee Type']).agg({'Units Sold':'sum','price':'mean'})
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df_c.groupby(['Coffee Type']).agg({'Units Sold':'sum'})
# Out:
#              Units Sold
# Coffee Type
# Espresso            265
# Latte               195

# %%
# pivot

pivot=df_c.pivot(columns='Coffee Type',index='Day')

pivot
# Out:
#             Units Sold
# Coffee Type   Espresso Latte
# Day
# Friday              45    35
# Monday              25    15
# Saturday            45    35
# Sunday              45    35
# Thursday            40    30
# Tuesday             30    20
# Wednesday           35    25

# %%
# pivot
pivot.loc['Monday']
# Out:
#             Coffee Type
# Units Sold  Espresso       25
#             Latte          15
# Name: Monday, dtype: int64

# %%
#
pivot.loc['Monday']
# Out:
#             Coffee Type
# Units Sold  Espresso       25
#             Latte          15
# Name: Monday, dtype: int64

# %%
# sum
pivot.sum()
# Out:
#             Coffee Type
# Units Sold  Espresso       265
#             Latte          195
# dtype: int64

# %%
# axis =1
pivot.sum(axis=1)
# Out:
# Day
# Friday       80
# Monday       40
# Saturday     80
# Sunday       80
# Thursday     70
# Tuesday      50
# Wednesday    60
# dtype: int64

# %%
# df_head()
df_c.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
df_c['Units Sold'].cumsum()
# Out:
# 0      25
# 1      40
# 2      70
# 3      90
# 4     125
# 5     150
# 6     190
# 7     220
# 8     265
# 9     300
# 10    345
# 11    380
# 12    425
# 13    460
# Name: Units Sold, dtype: int64
